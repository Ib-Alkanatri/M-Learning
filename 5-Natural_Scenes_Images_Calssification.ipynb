# %% [markdown]
# Image Classification Using CNN
# By : Ibrahim Alkanatri

# %% [markdown]
# we'll build a CNN using Keras to use it classifying thousands of pictures in 5 different categories
#
# Data link : https://www.kaggle.com/ibrahimalk/5natural-scenes-images-dataset
#
# first to import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid")
import os
import glob as gb
import cv2
import tensorflow as tf
import keras

# %% [markdown]
# now to define the path

# %%
trainpath = '../input/5-Natural_Scenes_Images_Dataset/'
testpath = '../input/5-Natural_Scenes_Images_Dataset/'
validationpath = '../input/5-Natural_Scenes_Images_Dataset/'

# %% [markdown]
# Open Folders
# now let's first check the Train folder to have a look to its content

# %%
for folder in  os.listdir(trainpath + 'train') : 
    files = gb.glob(pathname= str( trainpath +'train//' + folder + '/*.jpg'))
    print(f'For training data , found {len(files)} in folder {folder}')

# %% [markdown]
# ok , how about the test folder

# %%
for folder in  os.listdir(testpath +'test') : 
    files = gb.glob(pathname= str( testpath +'test//' + folder + '/*.jpg'))
    print(f'For testing data , found {len(files)} in folder {folder}')

# %% [markdown]
# Checking Images
# now we need to heck the images sizes , to know ow they looks like
#
# since we have 5 categories , we first need to create a dictionary with their names & indices , also create a function to get the code back

# %%
code = {'buildings':0 ,'forest':1,'glacier':2,'mountain':3,'sea':4 }

def getcode(n) : 
    for x , y in code.items() : 
        if n == y : 
            return x

# %% [markdown]
# now how about the images sizes in train folder

# %%
size = []
for folder in  os.listdir(trainpath +'train') : 
    files = gb.glob(pathname= str( trainpath +'train//' + folder + '/*.jpg'))
    for file in files: 
        image = plt.imread(file)
        size.append(image.shape)
pd.Series(size).value_counts()

# %% [markdown]
# ok , almost all of them are 150,150,3 , how about test images ?

# %%
size = []
for folder in  os.listdir(testpath +'test') : 
    files = gb.glob(pathname= str( testpath +'test//' + folder + '/*.jpg'))
    for file in files: 
        image = plt.imread(file)
        size.append(image.shape)
pd.Series(size).value_counts()

# %% [markdown]
# ok , since almost all of pictures are 150,150,3 , we can feel comfort in using all pictures in our model , after resizing it in a specific amount

# %% [markdown]
# Reading Images
# now it's time to read all images & convert it into arrays
#
# first we'll create a variable s , which refer to size , so we can change it easily
#
# let's use now size = 100 , so it will be suitable amount to contain accuracy without losing so much time in training

# %%
s = 100

# %% [markdown]
# now to read all pictues in five categories in training folder, ans use OpenCV to resize it , and not to forget to assign the y value , from the predefined function

# %%
X_train = []
y_train = []
for folder in  os.listdir(trainpath +'train') : 
    files = gb.glob(pathname= str( trainpath +'train//' + folder + '/*.jpg'))
    for file in files: 
        image = cv2.imread(file)
        image_array = cv2.resize(image , (s,s))
        X_train.append(list(image_array))
        y_train.append(code[folder])

# %% [markdown]
# great , now how many items in X_train

# %%
print(f'we have {len(X_train)} items in X_train')

# %% [markdown]
# also we have have a look to random pictures in X_train , and to adjust their title using the y value

# %%
plt.figure(figsize=(20,20))
for n , i in enumerate(list(np.random.randint(0,len(X_train),36))) : 
    plt.subplot(6,6,n+1)
    plt.imshow(X_train[i])   
    plt.axis('off')
    plt.title(getcode(y_train[i]))

# %% [markdown]
# great , now to repeat same steps exactly in test data

# %%
X_test = []
y_test = []
for folder in  os.listdir(testpath +'test') : 
    files = gb.glob(pathname= str(testpath + 'test//' + folder + '/*.jpg'))
    for file in files: 
        image = cv2.imread(file)
        image_array = cv2.resize(image , (s,s))
        X_test.append(list(image_array))
        y_test.append(code[folder])

# %%
print(f'we have {len(X_test)} items in X_test')

# %%
plt.figure(figsize=(20,20))
for n , i in enumerate(list(np.random.randint(0,len(X_test),36))) : 
    plt.subplot(6,6,n+1)
    plt.imshow(X_test[i])    
    plt.axis('off')
    plt.title(getcode(y_test[i]))

# %% [markdown]
# now to read all pictues in five categories in validation folder, ans use OpenCV to resize it , and not to forget to assign the y value , from the predefined function

# %%
X_val = []
y_val = []
for folder in  os.listdir(trainpath +'validation') : 
    files = gb.glob(pathname= str( trainpath +'validation//' + folder + '/*.jpg'))
    for file in files: 
        image = cv2.imread(file)
        image_array = cv2.resize(image , (s,s))
        X_val.append(list(image_array))
        y_val.append(code[folder])

# %% [markdown]
# Building The Model
# now we need to build the model to train our data
#
# first to convert the data into arrays using numpy

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
X_val = np.array(X_val)
y_train = np.array(y_train)
y_test = np.array(y_test)
y_val = np.array(y_val)
print(f'X_train shape  is {X_train.shape}')
print(f'X_test shape  is {X_test.shape}')

print(f'y_train shape  is {y_train.shape}')
print(f'y_test shape  is {y_test.shape}')

# %% [markdown]
# now to build the CNN model by Keras , using Conv2D layers , MaxPooling & Denses

# %%
KerasModel = keras.models.Sequential([
        keras.layers.Conv2D(200,kernel_size=(3,3),activation='relu',input_shape=(s,s,3)),
        keras.layers.Conv2D(150,kernel_size=(3,3),activation='relu'),
        
        keras.layers.MaxPool2D(4,4),
        keras.layers.Conv2D(120,kernel_size=(3,3),activation='relu'),    
        keras.layers.Conv2D(80,kernel_size=(3,3),activation='relu'),    
        keras.layers.Conv2D(50,kernel_size=(3,3),activation='relu'),
        
        keras.layers.MaxPool2D(4,4),
        keras.layers.Flatten() ,    
        keras.layers.Dense(120,activation='relu') ,    
        keras.layers.Dense(100,activation='relu') ,    
        keras.layers.Dense(50,activation='relu') ,        
        keras.layers.Dropout(rate=0.5) ,            
        keras.layers.Dense(5,activation='softmax') ,    
        ])

# %% [markdown]
# Instantiate the Tensorboard to make visualization for our model and its result.

# %% [markdown]
# now to compile the model , using adam optimizer , & sparse categorical crossentropy loss

# %%
KerasModel.compile(optimizer ='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# so how the model looks like ?

# %%
print('Model Details are : ')
print(KerasModel.summary())

# %% [markdown]
# now to train the model , lets use 50 epochs now

# %%
epochs = 50
ThisModel = KerasModel.fit(X_train, y_train, epochs=epochs,batch_size=256,verbose=1,validation_data=(X_val, y_val))
# Out:
# Train on 11652 samples, validate on 1000 samples
# Epoch 1/50
# 11652/11652 [==============================] - 31s 3ms/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 5.8187e-04 - val_accuracy: 1.0000
# Epoch 2/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0126 - accuracy: 0.9966 - val_loss: 3.4037e-04 - val_accuracy: 1.0000
# Epoch 3/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 2.0231e-04 - val_accuracy: 1.0000
# Epoch 4/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 8.6549e-05 - val_accuracy: 1.0000
# Epoch 5/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 4.2891e-05 - val_accuracy: 1.0000
# Epoch 6/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 2.9707e-05 - val_accuracy: 1.0000
# Epoch 7/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0016 - accuracy: 0.9991 - val_loss: 2.3332e-05 - val_accuracy: 1.0000
# Epoch 8/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 2.1417e-05 - val_accuracy: 1.0000
# Epoch 9/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 1.6812e-05 - val_accuracy: 1.0000
# Epoch 10/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 1.3926e-05 - val_accuracy: 1.0000
# Epoch 11/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0018 - accuracy: 0.9989 - val_loss: 1.3372e-05 - val_accuracy: 1.0000
# Epoch 12/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 1.2147e-05 - val_accuracy: 1.0000
# Epoch 13/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0015 - accuracy: 0.9991 - val_loss: 1.1097e-05 - val_accuracy: 1.0000
# Epoch 14/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 8.9896e-06 - val_accuracy: 1.0000
# Epoch 15/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 8.5145e-06 - val_accuracy: 1.0000
# Epoch 16/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 8.4407e-06 - val_accuracy: 1.0000
# Epoch 17/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0014 - accuracy: 0.9992 - val_loss: 8.8347e-06 - val_accuracy: 1.0000
# Epoch 18/50
# 11652/11652 [==============================] - 25s 2ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 9.3076e-06 - val_accuracy: 1.0000
# Epoch 19/50
# 11652/11652 [==============================] - 25s 2ms/step - loss: 0.0012 - accuracy: 0.9993 - val_loss: 8.4732e-06 - val_accuracy: 1.0000
# Epoch 20/50
# 11652/11652 [==============================] - 25s 2ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 8.4641e-06 - val_accuracy: 1.0000
# Epoch 21/50
# 11652/11652 [==============================] - 25s 2ms/step - loss: 0.0018 - accuracy: 0.9991 - val_loss: 3.0482e-05 - val_accuracy: 1.0000
# Epoch 22/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 1.6340e-05 - val_accuracy: 1.0000
# Epoch 23/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0013 - accuracy: 0.9993 - val_loss: 9.2740e-06 - val_accuracy: 1.0000
# Epoch 24/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 6.5648e-06 - val_accuracy: 1.0000
# Epoch 25/50
# 11652/11652 [==============================] - 25s 2ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 5.8596e-06 - val_accuracy: 1.0000
# Epoch 26/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0014 - accuracy: 0.9991 - val_loss: 5.7607e-06 - val_accuracy: 1.0000
# Epoch 27/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0015 - accuracy: 0.9991 - val_loss: 5.0551e-06 - val_accuracy: 1.0000
# Epoch 28/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0012 - accuracy: 0.9991 - val_loss: 3.6727e-06 - val_accuracy: 1.0000
# Epoch 29/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 3.3071e-06 - val_accuracy: 1.0000
# Epoch 30/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0015 - accuracy: 0.9988 - val_loss: 3.5238e-06 - val_accuracy: 1.0000
# Epoch 31/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0016 - accuracy: 0.9991 - val_loss: 4.3207e-06 - val_accuracy: 1.0000
# Epoch 32/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 3.8961e-06 - val_accuracy: 1.0000
# Epoch 33/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0016 - accuracy: 0.9991 - val_loss: 3.3288e-06 - val_accuracy: 1.0000
# Epoch 34/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 3.8068e-06 - val_accuracy: 1.0000
# Epoch 35/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 4.1002e-06 - val_accuracy: 1.0000
# Epoch 36/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0013 - accuracy: 0.9993 - val_loss: 4.0865e-06 - val_accuracy: 1.0000
# Epoch 37/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 3.2217e-06 - val_accuracy: 1.0000
# Epoch 38/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 5.5325e-05 - val_accuracy: 1.0000
# Epoch 39/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 2.6161e-06 - val_accuracy: 1.0000
# Epoch 40/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 3.7489e-06 - val_accuracy: 1.0000
# Epoch 41/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 2.2316e-06 - val_accuracy: 1.0000
# Epoch 42/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 3.9239e-05 - val_accuracy: 1.0000
# Epoch 43/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0014 - accuracy: 0.9991 - val_loss: 3.0815e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0015 - accuracy: 0.9991 - val_loss: 7.5905e-07 - val_accuracy: 1.0000
# Epoch 45/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 9.0478e-07 - val_accuracy: 1.0000
# Epoch 46/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0017 - accuracy: 0.9991 - val_loss: 7.0098e-07 - val_accuracy: 1.0000
# Epoch 47/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 1.7649e-06 - val_accuracy: 1.0000
# Epoch 48/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0276 - val_accuracy: 0.9970
# Epoch 49/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.2217 - accuracy: 0.9513 - val_loss: 0.0936 - val_accuracy: 0.9800
# Epoch 50/50
# 11652/11652 [==============================] - 26s 2ms/step - loss: 0.0419 - accuracy: 0.9879 - val_loss: 0.0164 - val_accuracy: 0.9940

# %% [markdown]
# how is the final loss & accuracy

# %%
ModelLoss, ModelAccuracy = KerasModel.evaluate(X_test, y_test)

print('Test Loss is {}'.format(ModelLoss))
print('Test Accuracy is {}'.format(ModelAccuracy ))
# Out:
# 2499/2499 [==============================] - 2s 734us/step
# Test Loss is 1.685263772681609
# Test Accuracy is 0.8503401279449463

# %% [markdown]
# # Visualization
# Visualize and plot the Accuracy and loss plots between training and validation data

# %%
accuracy = ThisModel.history['accuracy']
val_accuracy = ThisModel.history['val_accuracy']
loss = ThisModel.history['loss']
val_loss = ThisModel.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
